# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
transaction=pd.read_csv("Dim_transaction_type.csv")
customers=pd.read_csv("Dim_customers.csv")
florida=pd.read_csv("Florida.csv")

# %%
transaction
# Out:
#    TransactionTypeID TransactionTypeName
# 0                  1          Withdrawal
# 1                  2             Deposit
# 2                  3     Balance Inquiry
# 3                  4            Transfer

# %%
customers
# Out:
#      CardholderID  First Name  Last Name Gender   ATMID  Birth Date  \
# 0     RI-004-1018    Emmanuel   Akpobari      M  RI-004   2/14/2002
# 1     FC-005-1022      Habiba     Zainab      M  FC-005   6/28/1987
# 2     FC-005-1024  Abdulkadir      Sadiq      F  FC-005   9/28/2003
# 3     FC-006-1007  Adetokunbo    Adeniyi      M  FC-006   8/20/1978
# 4     FC-006-1036       Qudus    Ademola      F  FC-006   10/2/1985
# ...           ...         ...        ...    ...     ...         ...
# 8814  LA-007-1255      Quadri    Ibrahim      F  LA-007   6/19/1998
# 8815  LA-001-1255  Christiana   Akintoye      F  LA-001  12/11/1961
# 8816  LA-004-1147     Adeniyi  Oluwakemi      M  LA-004    2/7/2000
# 8817  LA-001-1011   Cornelius     Okafor      M  LA-001   1/24/1978
# 8818  LA-001-1033    Christie      Rasaq      F  LA-001    4/6/1960
#
#                       Occupation AccountType  IsMegabank
# 0                       Mechanic     Current           1
# 1                 Factory Worker     Current           0
# 2                         Trader     Current           1
# 3     Human Resources Specialist     Current           1
# 4                         Trader     Current           1
# ...                          ...         ...         ...
# 8814                     Student     Savings           1
# 8815                Data Analyst     Savings           0
# 8816                     Student     Savings           1
# 8817                Data Analyst     Current           0
# 8818                      Lawyer     Current           1
#
# [8819 rows x 9 columns]

# %%
florida
# Out:
#              TransactionID TransactionStartDateTime TransactionEndDateTime  \
# 0       FC-2022-1000000001         01/01/2022 05:00       01/01/2022 05:01
# 1       FC-2022-1000000002         01/01/2022 05:14       01/01/2022 05:16
# 2       FC-2022-1000000003         01/01/2022 05:14       01/01/2022 05:17
# 3       FC-2022-1000000004         01/01/2022 06:26       01/01/2022 06:31
# 4       FC-2022-1000000005         01/01/2022 06:27       01/01/2022 06:30
# ...                    ...                      ...                    ...
# 159647  FC-2022-1000159648         12/31/2022 18:55       12/31/2022 18:59
# 159648  FC-2022-1000159649         12/31/2022 18:55       12/31/2022 18:59
# 159649  FC-2022-1000159650         12/31/2022 18:58       12/31/2022 19:01
# 159650  FC-2022-1000159651         12/31/2022 18:58       12/31/2022 19:02
# 159651  FC-2022-1000159652         12/31/2022 18:59       12/31/2022 19:03
#
#        CardholderID LocationID  TransactionTypeID  TransactionAmount
# 0       FC-001-1015     FL-001                  3                  0
# 1       FC-001-1001     FL-001                  3                  0
# 2       FC-002-1045     FL-002                  2              10000
# 3       FC-004-1013     FL-004                  1              50000
# 4       FC-003-1023     FL-003                  2              10000
# ...             ...        ...                ...                ...
# 159647  FC-004-1003     FL-004                  2              20000
# 159648  FC-004-1003     FL-004                  1              50000
# 159649  FC-001-1004     FL-001                  1               6000
# 159650  FC-005-1039     FL-005                  1              10000
# 159651  FC-002-1040     FL-002                  4              10000
#
# [159652 rows x 7 columns]

# %%
florida.describe()
# Out:
#        TransactionTypeID  TransactionAmount
# count      159652.000000      159652.000000
# mean            2.000702       17830.475033
# std             1.242882       22328.106276
# min             1.000000           0.000000
# 25%             1.000000        3000.000000
# 50%             1.000000       10000.000000
# 75%             3.000000       20000.000000
# max             4.000000      100000.000000

# %%
transaction.dtypes
# Out:
# TransactionTypeID       int64
# TransactionTypeName    object
# dtype: object

# %%
customers.dtypes
# Out:
# CardholderID    object
# First Name      object
# Last Name       object
# Gender          object
# ATMID           object
# Birth Date      object
# Occupation      object
# AccountType     object
# IsMegabank       int64
# dtype: object

# %%
florida.dtypes
# Out:
# TransactionID               object
# TransactionStartDateTime    object
# TransactionEndDateTime      object
# CardholderID                object
# LocationID                  object
# TransactionTypeID            int64
# TransactionAmount            int64
# dtype: object

# %%
transaction.duplicated().sum()
customers.duplicated().sum()
florida.duplicated().sum()
# Out:
# np.int64(0)

# %%
transaction.isnull().sum()
customers.isnull().sum()
florida.isnull().sum()
# Out:
# TransactionID               0
# TransactionStartDateTime    0
# TransactionEndDateTime      0
# CardholderID                0
# LocationID                  0
# TransactionTypeID           0
# TransactionAmount           0
# dtype: int64

# %%
Q1 = florida['TransactionAmount'].quantile(0.25)
Q3 = florida['TransactionAmount'].quantile(0.75)
IQR = Q3 - Q1

lower_limit =0 # menfi oldugu ucun 0-a beraber etdim
upper_limit = Q3 + 1.5 * IQR    
outliers = florida[(florida['TransactionAmount'] < lower_limit) | (florida['TransactionAmount'] > upper_limit)]
outliers
# Out:
#              TransactionID TransactionStartDateTime TransactionEndDateTime  \
# 3       FC-2022-1000000004         01/01/2022 06:26       01/01/2022 06:31
# 5       FC-2022-1000000006         01/01/2022 06:27       01/01/2022 06:31
# 6       FC-2022-1000000007         01/01/2022 07:03       01/01/2022 07:05
# 15      FC-2022-1000000016         01/01/2022 07:15       01/01/2022 07:20
# 29      FC-2022-1000000030         01/01/2022 07:43       01/01/2022 07:48
# ...                    ...                      ...                    ...
# 159633  FC-2022-1000159634         12/31/2022 18:39       12/31/2022 18:43
# 159635  FC-2022-1000159636         12/31/2022 18:41       12/31/2022 18:46
# 159643  FC-2022-1000159644         12/31/2022 18:49       12/31/2022 18:52
# 159646  FC-2022-1000159647         12/31/2022 18:51       12/31/2022 18:54
# 159648  FC-2022-1000159649         12/31/2022 18:55       12/31/2022 18:59
#
#        CardholderID LocationID  TransactionTypeID  TransactionAmount
# 3       FC-004-1013     FL-004                  1              50000
# 5       FC-006-1010     FL-006                  1              50000
# 6       FC-004-1038     FL-004                  1              50000
# 15      FC-005-1006     FL-005                  4             100000
# 29      FC-006-1013     FL-006                  1              50000
# ...             ...        ...                ...                ...
# 159633  FC-005-1010     FL-005                  1              50000
# 159635  FC-002-1004     FL-002                  1              50000
# 159643  FC-004-1024     FL-004                  1              50000
# 159646  FC-001-1031     FL-001                  1              50000
# 159648  FC-004-1003     FL-004                  1              50000
#
# [33205 rows x 7 columns]

# %%
outliers
# Out:
#              TransactionID TransactionStartDateTime TransactionEndDateTime  \
# 3       FC-2022-1000000004         01/01/2022 06:26       01/01/2022 06:31
# 5       FC-2022-1000000006         01/01/2022 06:27       01/01/2022 06:31
# 6       FC-2022-1000000007         01/01/2022 07:03       01/01/2022 07:05
# 15      FC-2022-1000000016         01/01/2022 07:15       01/01/2022 07:20
# 29      FC-2022-1000000030         01/01/2022 07:43       01/01/2022 07:48
# ...                    ...                      ...                    ...
# 159633  FC-2022-1000159634         12/31/2022 18:39       12/31/2022 18:43
# 159635  FC-2022-1000159636         12/31/2022 18:41       12/31/2022 18:46
# 159643  FC-2022-1000159644         12/31/2022 18:49       12/31/2022 18:52
# 159646  FC-2022-1000159647         12/31/2022 18:51       12/31/2022 18:54
# 159648  FC-2022-1000159649         12/31/2022 18:55       12/31/2022 18:59
#
#        CardholderID LocationID  TransactionTypeID  TransactionAmount
# 3       FC-004-1013     FL-004                  1              50000
# 5       FC-006-1010     FL-006                  1              50000
# 6       FC-004-1038     FL-004                  1              50000
# 15      FC-005-1006     FL-005                  4             100000
# 29      FC-006-1013     FL-006                  1              50000
# ...             ...        ...                ...                ...
# 159633  FC-005-1010     FL-005                  1              50000
# 159635  FC-002-1004     FL-002                  1              50000
# 159643  FC-004-1024     FL-004                  1              50000
# 159646  FC-001-1031     FL-001                  1              50000
# 159648  FC-004-1003     FL-004                  1              50000
#
# [33205 rows x 7 columns]

# %%
florida['TransactionAmount'] = np.clip(florida['TransactionAmount'], lower_limit, upper_limit)
florida
# Out:
#              TransactionID TransactionStartDateTime TransactionEndDateTime  \
# 0       FC-2022-1000000001         01/01/2022 05:00       01/01/2022 05:01
# 1       FC-2022-1000000002         01/01/2022 05:14       01/01/2022 05:16
# 2       FC-2022-1000000003         01/01/2022 05:14       01/01/2022 05:17
# 3       FC-2022-1000000004         01/01/2022 06:26       01/01/2022 06:31
# 4       FC-2022-1000000005         01/01/2022 06:27       01/01/2022 06:30
# ...                    ...                      ...                    ...
# 159647  FC-2022-1000159648         12/31/2022 18:55       12/31/2022 18:59
# 159648  FC-2022-1000159649         12/31/2022 18:55       12/31/2022 18:59
# 159649  FC-2022-1000159650         12/31/2022 18:58       12/31/2022 19:01
# 159650  FC-2022-1000159651         12/31/2022 18:58       12/31/2022 19:02
# 159651  FC-2022-1000159652         12/31/2022 18:59       12/31/2022 19:03
#
#        CardholderID LocationID  TransactionTypeID  TransactionAmount
# 0       FC-001-1015     FL-001                  3                  0
# 1       FC-001-1001     FL-001                  3                  0
# 2       FC-002-1045     FL-002                  2              10000
# 3       FC-004-1013     FL-004                  1              45500
# 4       FC-003-1023     FL-003                  2              10000
# ...             ...        ...                ...                ...
# 159647  FC-004-1003     FL-004                  2              20000
# 159648  FC-004-1003     FL-004                  1              45500
# 159649  FC-001-1004     FL-001                  1               6000
# 159650  FC-005-1039     FL-005                  1              10000
# 159651  FC-002-1040     FL-002                  4              10000
#
# [159652 rows x 7 columns]

# %%
#1• Məbləğlərin minimumunu, maksimumunu, ortalamasını ve standard dağılmasını müəyyənləşdirin.
florida["TransactionAmount"].min()
# Out:
# np.int64(0)

# %%
florida["TransactionAmount"].max()
# Out:
# np.int64(45500)

# %%
florida["TransactionAmount"].mean()
# Out:
# np.float64(15469.261268258462)

# %%
florida["TransactionAmount"].std()
# Out:
# np.float64(16552.8437370975)

# %%
#2• Hər bir əməliyyatın müddətini əks etdirən yeni sütun yaradın (TransactionEndDatetime - TransactionStartDatetime)
florida["TransactionStartDateTime"]=pd.to_datetime(florida["TransactionStartDateTime"],format='%m/%d/%Y %H:%M')
florida["TransactionEndDateTime"]=pd.to_datetime(florida["TransactionEndDateTime"],format='%m/%d/%Y %H:%M')

# %%
florida['TransactionDuration'] = (florida['TransactionEndDateTime'] - florida['TransactionStartDateTime']).dt.total_seconds()

# %%
florida
# Out:
#              TransactionID TransactionStartDateTime TransactionEndDateTime  \
# 0       FC-2022-1000000001      2022-01-01 05:00:00    2022-01-01 05:01:00
# 1       FC-2022-1000000002      2022-01-01 05:14:00    2022-01-01 05:16:00
# 2       FC-2022-1000000003      2022-01-01 05:14:00    2022-01-01 05:17:00
# 3       FC-2022-1000000004      2022-01-01 06:26:00    2022-01-01 06:31:00
# 4       FC-2022-1000000005      2022-01-01 06:27:00    2022-01-01 06:30:00
# ...                    ...                      ...                    ...
# 159647  FC-2022-1000159648      2022-12-31 18:55:00    2022-12-31 18:59:00
# 159648  FC-2022-1000159649      2022-12-31 18:55:00    2022-12-31 18:59:00
# 159649  FC-2022-1000159650      2022-12-31 18:58:00    2022-12-31 19:01:00
# 159650  FC-2022-1000159651      2022-12-31 18:58:00    2022-12-31 19:02:00
# 159651  FC-2022-1000159652      2022-12-31 18:59:00    2022-12-31 19:03:00
#
#        CardholderID LocationID  TransactionTypeID  TransactionAmount  \
# 0       FC-001-1015     FL-001                  3                  0
# 1       FC-001-1001     FL-001                  3                  0
# 2       FC-002-1045     FL-002                  2              10000
# 3       FC-004-1013     FL-004                  1              45500
# 4       FC-003-1023     FL-003                  2              10000
# ...             ...        ...                ...                ...
# 159647  FC-004-1003     FL-004                  2              20000
# 159648  FC-004-1003     FL-004                  1              45500
# 159649  FC-001-1004     FL-001                  1               6000
# 159650  FC-005-1039     FL-005                  1              10000
# 159651  FC-002-1040     FL-002                  4              10000
#
#         TransactionDuration
# 0                      60.0
# 1                     120.0
# 2                     180.0
# 3                     300.0
# 4                     180.0
# ...                     ...
# 159647                240.0
# 159648                240.0
# 159649                180.0
# 159650                240.0
# 159651                240.0
#
# [159652 rows x 8 columns]

# %%
#3• Hər bir ATM və Tranzaksiya tipine göre qiymətlər haqqında məlumat verən pivot table yaradın.

# %%
merged_df=pd.merge(florida,transaction,on='TransactionTypeID',how="left")

# %%
merged_df=pd.merge(merged_df,customers,on='CardholderID',how="left")

# %%
pivot_table = pd.pivot_table(merged_df, values='TransactionAmount', index='ATMID', columns='TransactionTypeName', aggfunc='sum', fill_value=0)
pivot_table
# Out:
# TransactionTypeName  Balance Inquiry   Deposit   Transfer  Withdrawal
# ATMID
# FC-001                             0  32877000  122501000   304733000
# FC-002                             0  33233000  120830000   313772000
# FC-003                             0  22319000   81234000   219430000
# FC-004                             0  30547000  111560500   287429000
# FC-005                             0  30811000  110907500   286960500
# FC-006                             0  26122000   93102000   241330000

# %%
#4• Ən yüksək ümumi əməliyyat məbləği olan kart sahibini müəyyənləşdirin.

# %%
total_transaction=florida.groupby("CardholderID")["TransactionAmount"].sum()
cardholderid=total_transaction.idxmax()

# %%
cardholderid
# Out:
# 'FC-001-1006'

# %%
total_transaction_amount=total_transaction.max()
total_transaction_amount
# Out:
# np.int64(11341500)

# %%
#5• Qadınlar və kişilərin tranzaksiya məbləği arasında gözə çarpan ferqin olub olmamasini hipotez testi vasitəsilə araşdırın
from scipy.stats import ttest_ind
merged_gender_df = pd.merge(florida, customers[['CardholderID', 'Gender']], on='CardholderID', how='left')
female_amounts = merged_gender_df[merged_gender_df['Gender'] == 'F']['TransactionAmount']
male_amounts = merged_gender_df[merged_gender_df['Gender'] == 'M']['TransactionAmount']
t_stat, p_value = ttest_ind(male_amounts, female_amounts, equal_var=False)
if p_value < 0.05:
    print("Nəticə: Qadınlar və kişilərin tranzaksiya məbləğləri arasında əhəmiyyətli fərq var.")
else:
    print("Nəticə: Əhəmiyyətli fərq tapılmadı.")
# Out:
# Nəticə: Əhəmiyyətli fərq tapılmadı.

# %%
#6• Əməliyyatları "Location Name" üzrə qruplaşdırın və ən yüksək əməliyyat sayına malik yeri tapın

# %%
transaction_count=florida.groupby('LocationID')['TransactionID'].count()
transaction_count
# Out:
# LocationID
# FL-001    29828
# FL-002    30352
# FL-003    20747
# FL-004    27875
# FL-005    27560
# FL-006    23290
# Name: TransactionID, dtype: int64

# %%
highest_transaction=transaction_count.idxmax()
highest_transaction
# Out:
# 'FL-002'

# %%
highest_transaction_count=transaction_count.max()
highest_transaction_count
# Out:
# np.int64(30352)

# %%
#7• Tranzaksiya məbləğlərini vizuallaşdırmaq üçün bar diaqramları və ya histoqramlar yaradın
plt.figure(figsize=(10, 6))
sns.histplot(florida['TransactionAmount'], bins=30, kde=True)
plt.title('Distribution of Transaction Amounts')
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')
plt.show()

# %%
#8• Tranzaksiya tipləri ilə bağlı pie diaqramı yaradın.

# %%
merged_df=pd.merge(florida,transaction,on="TransactionTypeID",how="left")
transaction_type_counts=merged_df["TransactionTypeName"].value_counts()
plt.figure(figsize=(8,8))
transaction_type_counts.plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('Set3'))
plt.title("Transaction Type Distribution")
plt.show()

# %%
average_transaction = florida.groupby('LocationID')['TransactionAmount'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='LocationID', y='TransactionAmount', data=average_transaction,hue='LocationID', palette='viridis')
plt.title('sum Transaction Amount by Location')
plt.xlabel('Location ID')
plt.ylabel('sum Transaction Amount')
plt.xticks(rotation=45)
plt.show()
